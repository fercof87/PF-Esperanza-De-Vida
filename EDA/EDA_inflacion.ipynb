# %% [markdown]
# # Análisis Exploratorio de Datos

# %% [markdown]
# Se importa las librerias a utilizar

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Se crea un DataFrame con los datos de la Categoría inflación

# %%
df = pd.read_csv('data_inflacion.csv')

# %% [markdown]
# Un .info() para tener idea de cuantas columnas y que tipo de datos hay en cada una de ellas, y si tenemos datos Nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 40 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   país            88 non-null     object
#  1   codigo_pais     88 non-null     object
#  2   factor_(serie)  88 non-null     object
#  3   codigo_serie    88 non-null     object
#  4   1987            77 non-null     float64
#  5   1988            77 non-null     float64
#  6   1989            77 non-null     float64
#  7   1990            78 non-null     float64
#  8   1991            78 non-null     float64
#  9   1992            78 non-null     float64
#  10  1993            79 non-null     float64
#  11  1994            79 non-null     float64
#  12  1995            80 non-null     float64
#  13  1996            81 non-null     float64
#  14  1997            81 non-null     float64
#  15  1998            81 non-null     float64
#  16  1999            81 non-null     float64
#  17  2000            81 non-null     float64
#  18  2001            81 non-null     float64
#  19  2002            81 non-null     float64
#  20  2003            82 non-null     float64
#  21  2004            82 non-null     float64
#  22  2005            83 non-null     float64
#  23  2006            83 non-null     float64
#  24  2007            84 non-null     float64
#  25  2008            85 non-null     float64
#  26  2009            86 non-null     float64
#  27  2010            86 non-null     float64
#  28  2011            86 non-null     float64
#  29  2012            86 non-null     float64
#  30  2013            86 non-null     float64
#  31  2014            86 non-null     float64
#  32  2015            85 non-null     float64
#  33  2016            85 non-null     float64
#  34  2017            84 non-null     float64
#  35  2018            84 non-null     float64
#  36  2019            84 non-null     float64
#  37  2020            83 non-null     float64
#  38  2021            83 non-null     float64
#  39  2022            80 non-null     float64
# dtypes: float64(36), object(4)
# memory usage: 27.6+ KB

# %%
df.head()
# Out:
#          país codigo_pais                                    factor_(serie)  \
# 0  Afganistán         AFG  Inflación, índice de deflación del PIB (% anual)
# 1  Afganistán         AFG        Inflación, precios al consumidor (% anual)
# 2    Alemania         DEU  Inflación, índice de deflación del PIB (% anual)
# 3    Alemania         DEU        Inflación, precios al consumidor (% anual)
# 4     Argelia         DZA  Inflación, índice de deflación del PIB (% anual)
#
#         codigo_serie    1987    1988     1989     1990     1991     1992  ...  \
# 0  NY.GDP.DEFL.KD.ZG     NaN     NaN      NaN      NaN      NaN      NaN  ...
# 1     FP.CPI.TOTL.ZG     NaN     NaN      NaN      NaN      NaN      NaN  ...
# 2  NY.GDP.DEFL.KD.ZG  1.2797  1.6905   2.8791   3.3966   3.0851   5.3062  ...
# 3     FP.CPI.TOTL.ZG  0.2499  1.2741   2.7806   2.6965   4.0470   5.0570  ...
# 4  NY.GDP.DEFL.KD.ZG  8.8420  9.0610  16.0114  30.2596  53.7886  21.9261  ...
#
#      2013    2014    2015    2016    2017    2018    2019    2020     2021  \
# 0  4.8228  0.5669  2.4476 -2.1975  2.4037  2.0713  6.5215  7.8217   0.4774
# 1  7.3858  4.6740 -0.6617  4.3839  4.9760  0.6261  2.3024     NaN      NaN
# 2  1.9594  1.8779  1.8537  1.3278  1.5037  2.0075  2.1244  1.8108   3.0576
# 3  1.5047  0.9068  0.5144  0.4917  1.5095  1.7322  1.4457  0.1449   3.0667
# 4 -0.0933 -0.3006 -6.4557  1.5489  6.3907  6.7573 -0.4722 -5.0259  15.5672
#
#       2022
# 0      NaN
# 1      NaN
# 2   5.4828
# 3   6.8726
# 4  19.7109
#
# [5 rows x 40 columns]

# %% [markdown]
# Se utiliza .describe() para obtener una visión general de las estadísticas clave de las columnas numéricas en tu conjunto de datos

# %%
df.describe().round(2)
# Out:
#          1987    1988     1989     1990    1991     1992     1993     1994  \
# count   77.00   77.00    77.00    78.00   78.00    78.00    79.00    79.00
# mean    18.95   32.06    84.77   110.48   25.33    52.49    79.32    73.79
# std     45.25  108.46   405.53   504.13   70.50   224.21   335.27   341.83
# min     -8.70  -11.61    -3.69    -0.78   -7.80   -12.91    -8.43    -0.26
# 25%      1.68    2.79     2.92     3.53    3.13     1.86     1.66     1.94
# 50%      5.25    6.38     5.76     6.94    5.90     4.97     3.63     6.97
# 75%     11.47   13.42    13.79    16.47   18.62    15.35    13.49    22.16
# max    228.34  629.11  3046.09  2947.73  432.79  1490.42  1996.15  2240.17
#
#          1995    1996  ...   2013   2014    2015    2016   2017   2018   2019  \
# count   80.00   81.00  ...  86.00  86.00   85.00   85.00  84.00  84.00  84.00
# mean    14.89    9.54  ...   3.78   4.16    3.61    5.91   3.95   3.88   2.79
# std     30.00   15.82  ...   6.44   9.03   14.11   27.84   5.53   5.64   5.87
# min     -6.98   -2.67  ...  -4.14  -2.25  -16.58   -5.53  -1.54  -0.64  -3.23
# 25%      2.14    1.57  ...   0.98   0.56    0.37    0.42   1.29   1.61   0.68
# 50%      5.52    4.82  ...   2.29   1.89    1.51    1.73   2.27   2.28   1.88
# 75%     11.46    8.98  ...   5.13   4.50    3.97    4.95   4.48   4.20   3.43
# max    197.41  115.52  ...  40.64  62.17  121.74  254.95  29.52  42.03  49.20
#
#         2020    2021   2022
# count  83.00   83.00  80.00
# mean    2.40    9.57   8.97
# std     5.82   44.09   8.75
# min   -12.03   -3.45  -5.51
# 25%     0.15    1.90   5.34
# 50%     1.38    3.12   7.08
# 75%     3.42    5.90   9.27
# max    40.08  401.59  69.68
#
# [8 rows x 36 columns]

# %% [markdown]
# Para conocer si tenemos valores faltantes en las columnas de ['país'] ['codigo_pais'] ['factor_(serie)'] ['codigo_serie']

# %%
print(df['país'].isna().sum())
print(df['codigo_pais'].isna().sum())
print(df['factor_(serie)'].isna().sum())
print(df['codigo_serie'].isna().sum())
# Out:
# 0
# 0
# 0
# 0

# %% [markdown]
# Veamos en que países se encuentran en estudio.

# %%
cantidad_paises = len(df['país'].unique())
print('Cantidad de paises en estudio:',cantidad_paises)
pd.DataFrame(df['país'].unique(), columns=['Países'])
# Out:
# Cantidad de paises en estudio: 44
#                         Países
# 0                   Afganistán
# 1                     Alemania
# 2                      Argelia
# 3               Arabia Saudita
# 4                    Argentina
# 5                    Australia
# 6                      Austria
# 7                       Brasil
# 8                 Burkina Faso
# 9                        China
# 10                      Canadá
# 11                     Camboya
# 12                        Chad
# 13                   Dinamarca
# 14                     Ecuador
# 15      Emiratos Árabes Unidos
# 16  Egipto, República Árabe de
# 17                        Cuba
# 18                  Costa Rica
# 19              Estados Unidos
# 20                      España
# 21                        Fiji
# 22                   Finlandia
# 23         Federación de Rusia
# 24                      Grecia
# 25                       India
# 26                   Marruecos
# 27                      México
# 28                       Nepal
# 29                       Níger
# 30                Países Bajos
# 31              Nueva Zelandia
# 32                 Reino Unido
# 33                      Rwanda
# 34                       Samoa
# 35                Sierra Leona
# 36                   Sudáfrica
# 37                    Singapur
# 38                       Suiza
# 39                   Venezuela
# 40                    Colombia
# 41                       Japón
# 42                       Kenya
# 43                     Noruega

# %% [markdown]
# Veamos Variables se estudia

# %%
cantidad_series = len(df['factor_(serie)'].unique())
print('Cantidad de variables estudio:',cantidad_series)
serie_unicos = df['factor_(serie)'].unique()
print(serie_unicos)
# Out:
# Cantidad de variables estudio: 2
# ['Inflación, índice de deflación del PIB (% anual)'
#  'Inflación, precios al consumidor (% anual)']

# %%
grupos = df.groupby('factor_(serie)').groups

# %%
grupos = df.groupby('factor_(serie)')

# Iterar a través de los grupos y convertirlos en DataFrames individuales
dataframes_por_grupo = {}
for nombre_grupo, grupo in grupos:
    dataframes_por_grupo[nombre_grupo] = grupo.reset_index(drop=True)

# Ahora dataframes_por_grupo contiene un DataFrame por cada grupo

# %%
dataframes_por_grupo['Inflación, índice de deflación del PIB (% anual)']
# Out:
#                           país codigo_pais  \
# 0                   Afganistán         AFG
# 1                     Alemania         DEU
# 2                      Argelia         DZA
# 3               Arabia Saudita         SAU
# 4                    Argentina         ARG
# 5                    Australia         AUS
# 6                      Austria         AUT
# 7                       Brasil         BRA
# 8                 Burkina Faso         BFA
# 9                        China         CHN
# 10                      Canadá         CAN
# 11                     Camboya         KHM
# 12                        Chad         TCD
# 13                   Dinamarca         DNK
# 14                     Ecuador         ECU
# 15      Emiratos Árabes Unidos         ARE
# 16  Egipto, República Árabe de         EGY
# 17                        Cuba         CUB
# 18                  Costa Rica         CRI
# 19              Estados Unidos         USA
# 20                      España         ESP
# 21                        Fiji         FJI
# 22                   Finlandia         FIN
# 23         Federación de Rusia         RUS
# 24                      Grecia         GRC
# 25                       India         IND
# 26                   Marruecos         MAR
# 27                      México         MEX
# 28                       Nepal         NPL
# 29                       Níger         NER
# 30                Países Bajos         NLD
# 31              Nueva Zelandia         NZL
# 32                 Reino Unido         GBR
# 33                      Rwanda         RWA
# 34                       Samoa         WSM
# 35                Sierra Leona         SLE
# 36                   Sudáfrica         ZAF
# 37                    Singapur         SGP
# 38                       Suiza         CHE
# 39                   Venezuela         VEN
# 40                    Colombia         COL
# 41                       Japón         JPN
# 42                       Kenya         KEN
# 43                     Noruega         NOR
#
#                                       factor_(serie)       codigo_serie  \
# 0   Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 1   Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 2   Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 3   Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 4   Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 5   Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 6   Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 7   Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 8   Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 9   Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 10  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 11  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 12  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 13  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 14  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 15  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 16  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 17  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 18  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 19  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 20  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 21  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 22  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 23  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 24  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 25  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 26  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 27  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 28  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 29  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 30  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 31  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 32  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 33  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 34  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 35  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 36  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 37  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 38  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 39  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 40  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 41  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 42  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 43  Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
#
#         1987      1988       1989       1990      1991       1992  ...  \
# 0        NaN       NaN        NaN        NaN       NaN        NaN  ...
# 1     1.2797    1.6905     2.8791     3.3966    3.0851     5.3062  ...
# 2     8.8420    9.0610    16.0114    30.2596   53.7886    21.9261  ...
# 3     6.7414   -8.9486     8.5775     7.1017   -2.2625    -0.2966  ...
# 4   127.5399  381.2463  3046.0912  2078.3168  140.5024    16.0720  ...
# 5     7.0330    7.1753     9.2338     6.0968    3.0217     1.4789  ...
# 6     2.4369    1.5269     2.9648     2.9997    3.6419     3.4791  ...
# 7   206.2087  627.9515  1304.4242  2736.9707  416.6781   969.0130  ...
# 8     1.2373    3.4086     4.8316     1.8100   -3.9678     0.2271  ...
# 9     5.0825   12.1077     8.6025     5.7112    6.7145     8.1903  ...
# 10    4.7907    4.5407     4.7021     3.3918    3.0515     1.4610  ...
# 11       NaN       NaN        NaN        NaN       NaN        NaN  ...
# 12   -3.1331    9.3619    -1.2526     8.0123    3.0735   -12.9066  ...
# 13    4.7547    3.9446     4.9653     2.6024    2.6595     1.6559  ...
# 14   -8.7010  -11.6138     5.3680     5.8136    6.8893     4.3032  ...
# 15    3.6856    2.3810     1.7513     3.3359    0.8108     1.8068  ...
# 16   12.4694   13.4176    19.1374    17.7431   16.1253    18.3508  ...
# 17    0.6105    1.2332     0.6248     5.2613   -7.3878     3.7457  ...
# 18   10.1444   18.8393    15.2483    18.5479   64.7747    19.7289  ...
# 19    2.4728    3.5274     3.9203     3.7433    3.3818     2.2789  ...
# 20    5.9442    5.9361     6.8962     7.3263    6.9351     6.7108  ...
# 21    7.3400    7.3280     2.8483     6.6795    5.9931     6.3067  ...
# 22    4.2841    7.6831     6.5301     5.1954    1.5118     0.8877  ...
# 23       NaN       NaN        NaN    15.9029  128.6298  1490.4184  ...
# 24   15.2527   16.6799    14.4990    20.6906   19.7877    14.7988  ...
# 25    9.3279    8.2325     8.4368    10.6683   13.7518     8.9652  ...
# 26    3.0148    3.6706     2.9200     7.6944    5.3963     4.5879  ...
# 27  142.0088  100.4554    27.3581    28.1566   23.6399    14.8810  ...
# 28   12.6968   11.8153    11.2584    10.7159   12.5446    18.4891  ...
# 29    1.6846   -5.3000     1.4000    39.3600   -2.6407    -5.2019  ...
# 30   -1.0476    0.8196     1.3481     1.5598    3.1170     2.4957  ...
# 31   11.4711    7.9076     5.6395     2.4236    0.8903     2.0014  ...
# 32    5.4405    6.1332     7.9359     7.8862    6.4191     3.3210  ...
# 33    0.6653    2.2254     5.2971    13.4615   14.9789     7.2833  ...
# 34    4.5174   18.3740    -2.7921     9.0064    6.1114     8.5660  ...
# 35  165.6766   64.2882    61.4913    70.5915  128.7617    82.0236  ...
# 36   14.8480   15.4208    17.0817    15.4454   15.6545    14.7140  ...
# 37    0.5324    5.4307     4.1592     4.6974    4.4353     1.3877  ...
# 38    2.1935    2.7902     3.4585     4.6036    5.4091     2.1246  ...
# 39   37.4445   18.4977    89.1631    41.7407   21.4496    28.2441  ...
# 40   23.3769   27.7501    24.6858    52.3361   27.0058    22.6644  ...
# 41   -0.0798    0.7417     2.0430     2.6560    2.8226     1.6137  ...
# 42    5.4020    6.4556     9.7690    10.6372   12.5320    18.8972  ...
# 43    7.2213    4.8685     5.6123     3.8116    2.2118    -0.6398  ...
#
#        2013     2014     2015     2016     2017     2018     2019     2020  \
# 0    4.8228   0.5669   2.4476  -2.1975   2.4037   2.0713   6.5215   7.8217
# 1    1.9594   1.8779   1.8537   1.3278   1.5037   2.0075   2.1244   1.8108
# 2   -0.0933  -0.3006  -6.4557   1.5489   6.3907   6.7573  -0.4722  -5.0259
# 3   -1.1967  -2.2470 -16.5815  -2.8170   7.4315  15.2215  -1.7648  -8.4632
# 4   23.9488  40.2830  26.5800  41.1194  26.0064  42.0337  49.1956  40.0769
# 5   -0.1536   1.4258  -0.5943  -0.6052   3.7433   1.8292   3.3977   1.7397
# 6    1.6239   2.1757   2.3010   1.8483   1.0055   1.8381   1.5467   2.5586
# 7    7.5046   7.8467   7.5662   8.1036   3.6714   4.4935   4.2243   6.4725
# 8   -2.1292  -0.6204  -2.2240   2.6043   1.4163   1.0740   1.6171   6.8350
# 9    2.1634   1.0311  -0.0029   1.4073   4.2327   3.4997   1.2867   0.4925
# 10   1.7374   1.9446  -0.8767   0.7540   2.5650   1.6174   1.5662   0.6155
# 11   0.7814   2.6322   1.7861   3.4753   3.3410   3.1118   3.2354  -0.6719
# 12  -4.1414   0.6458  -8.4800  -1.4008   0.0283   5.0147   2.8560  -5.4549
# 13   0.8882   1.0321   0.4331   0.2546   1.1847   0.7479   1.0488   2.6076
# 14   3.0950   3.0307  -2.4910   1.9016   1.9464   1.8189   0.4955  -0.3991
# 15  -0.9493  -0.6680 -16.2670  -5.5295   4.9862   7.9367  -3.1944 -12.0313
# 16   8.7127  11.2476   9.9309   6.2457  29.5185  21.1748  13.6181   6.1769
# 17   2.6578   3.4632   3.4396   4.3267   4.1152   1.0313   3.5470  16.5548
# 18   4.5902   6.2069   3.9552   1.9588   2.8589   2.1925   2.5668   0.7726
# 19   1.7509   1.8699   1.0005   1.0022   1.8996   2.4041   1.7939   1.3049
# 20   0.3977  -0.2237   0.5453   0.3221   1.2992   1.2456   1.4474   1.2256
# 21   3.6213  12.5054   2.5309   2.6333   1.6985   1.4257   2.2435  -1.2161
# 22   2.5583   1.6316   1.6167   0.0874   0.8193   2.0018   1.4966   1.6347
# 23   5.3201   7.4901   7.2497   2.8442   5.3498   9.9980   3.2631   0.8982
# 24  -2.0456  -1.9388  -0.2937  -0.5786   0.2854  -0.1652   0.2241  -0.8609
# 25   6.1865   3.3318   2.2796   3.2380   3.9693   3.8842   2.4055   4.7465
# 26   1.2603   0.2154   3.1729   0.9699  -0.0609   0.9392   0.8168   0.1470
# 27   1.5297   4.4397   2.8351   5.6053   6.7127   4.9464   4.1238   4.1673
# 28   7.0827   8.0354   4.4090   7.1503   8.2614   4.3559   4.6912   3.2174
# 29  -0.3692  -0.4057   2.2494   1.7927   0.3721   2.1758   0.4069   0.9492
# 30   1.2800   0.2532   0.7727   0.4547   1.2607   2.4371   3.0327   1.9286
# 31   4.1568   0.4161   1.4312   2.3481   3.5172   1.7524   3.1001   2.0113
# 32   2.1713   1.2778   0.7126   1.8786   1.7912   1.7379   2.1134   5.9331
# 33   2.6906   4.7322   0.4863   5.0293   8.1429  -0.6391   2.4444   6.7239
# 34   2.3463   0.8531   3.9647   2.2448   0.3049   1.0976   1.4995   1.2236
# 35   6.9591   1.7954  19.6403   5.8517   8.9560  14.0106   7.7028  10.9150
# 36   5.8441   5.3665   5.5455   6.9522   5.4733   3.7458   4.6381   5.6926
# 37  -0.4311  -0.2673   3.0720   0.4695   2.8752   3.5347  -0.2016  -2.6965
# 38  -0.0868  -0.6531  -1.2651  -0.5833  -0.3679   0.7643  -0.1039  -0.7412
# 39  35.5027  40.4405      NaN      NaN      NaN      NaN      NaN      NaN
# 40   1.9077   2.2356   2.4493   5.1483   5.1337   4.6306   4.0026   1.4802
# 41  -0.3544   1.6863   2.1113   0.4199  -0.0743  -0.0002   0.6348   0.9442
# 42   7.3376   7.6350   9.2387   5.8496   7.5819   4.2150   4.2752   4.9489
# 43   2.5532   0.2583  -2.8045  -1.5981   4.0809   6.7429  -0.5484  -2.5173
#
#         2021     2022
# 0     0.4774      NaN
# 1     3.0576   5.4828
# 2    15.5672  19.7109
# 3    13.8282  17.3220
# 4    54.1524  69.6829
# 5     2.8009   7.1147
# 6     1.9434   4.9735
# 7    11.3841   8.2832
# 8    -0.8166   6.0542
# 9     4.5533   2.2473
# 10    8.1533   7.3326
# 11    1.2919   5.7422
# 12    7.2000  18.6558
# 13    2.7666   7.6208
# 14    2.5793   5.2648
# 15   14.2808  13.8534
# 16    4.8472  10.4258
# 17  401.5883      NaN
# 18    1.9780   5.7646
# 19    4.4928   7.0053
# 20    2.3010   4.2803
# 21   -3.4466   5.3407
# 22    2.1624   4.2465
# 23   18.9905  15.8047
# 24    1.2922   8.1135
# 25    8.5385   8.3182
# 26    3.2442   5.0347
# 27    5.1641   7.0322
# 28    6.7627   7.3274
# 29    3.1186  -5.5118
# 30    2.4187   5.3040
# 31    4.8049   5.6466
# 32    0.0166   5.4107
# 33    2.7248  16.0322
# 34   -0.4037   6.3852
# 35    6.6915  21.4790
# 36    6.2190   5.0543
# 37    8.7844   9.0518
# 38    1.0599   3.2804
# 39       NaN      NaN
# 40    7.6676  14.1885
# 41   -0.2275   0.2445
# 42    4.3307   6.0088
# 43   17.1026  28.0333
#
# [44 rows x 40 columns]

# %%
# Iterar sobre los dataframes
for nombre_grupo, dataframe in dataframes_por_grupo.items():
    # Obtener la lista de columnas para graficar (años)
    columnas_años = dataframe.columns[4:]
    
    # Configurar el gráfico
    plt.figure(figsize=(10, 6))
    plt.title(f'Gráfico para {nombre_grupo}')
    plt.xlabel('Año')
    plt.ylabel('Valor')
    
    # Iterar a través de las filas (paises)
    for i in range(len(dataframe)):
        # Obtener los valores (suponiendo que los valores comienzan en la cuarta columna)
        valores = dataframe.iloc[i, 4:]
        plt.plot(columnas_años, valores, label=dataframe.iloc[i, 0])  # El nombre del país está en la primera columna
    
    # Mostrar leyenda y gráfico
    # Posicionar la leyenda afuera del gráfico
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    # Rotar las etiquetas del eje x a 90 grados
    plt.xticks(rotation=90)
    plt.show()
