# %%
import pandas as pd

# %%
df1 = pd.read_csv('data_educacion.csv')
df2 = pd.read_csv('data_esperanza_vida.csv')
df3 = pd.read_csv('data_gasto_salud.csv')
df4 = pd.read_csv('data_inflacion.csv')

# %%
df_concat = pd.concat([df1,df2,df3,df4])

# %%
df_concat.sort_values('país', inplace=True)

# %%
#df_concat.to_csv('merge_data.csv', index=False)

# %%
df = pd.read_csv('merge_data.csv')

# %%
df
# Out:
#            país codigo_pais  \
# 0    Afganistán         AFG
# 1    Afganistán         AFG
# 2    Afganistán         AFG
# 3    Afganistán         AFG
# 4    Afganistán         AFG
# ..          ...         ...
# 523   Venezuela         VEN
# 524   Venezuela         VEN
# 525   Venezuela         VEN
# 526   Venezuela         VEN
# 527   Venezuela         VEN
#
#                                         factor_(serie)       codigo_serie  \
# 0    Nivel de instrucción, al menos ciclo inferior ...  SE.SEC.CUAT.LO.ZS
# 1           Esperanza de vida al nacer, varones (años)  SP.DYN.LE00.MA.IN
# 2           Inflación, precios al consumidor (% anual)     FP.CPI.TOTL.ZG
# 3     Inflación, índice de deflación del PIB (% anual)  NY.GDP.DEFL.KD.ZG
# 4    Gasto nacional en salud del gobierno general p...  SH.XPD.GHED.PC.CD
# ..                                                 ...                ...
# 523        Gasto de bolsillo per cápita (US$ actuales)  SH.XPD.OOPC.PC.CD
# 524  Gasto nacional en salud del gobierno general p...  SH.XPD.GHED.PC.CD
# 525  Nivel de instrucción, al menos ciclo superior ...  SE.SEC.CUAT.UP.ZS
# 526  Nivel de instrucción, al menos ciclo inferior ...  SE.SEC.CUAT.LO.ZS
# 527  Nivel de instrucción, al menos escuela de nive...  SE.SEC.CUAT.PO.ZS
#
#        1987    1988    1989     1990    1991   1992  ...      2013      2014  \
# 0       NaN     NaN     NaN      NaN     NaN    NaN  ...       NaN       NaN
# 1    36.739  41.572  42.891  43.7090  44.353  45.07  ...   60.7910   60.8120
# 2       NaN     NaN     NaN      NaN     NaN    NaN  ...    7.3858    4.6740
# 3       NaN     NaN     NaN      NaN     NaN    NaN  ...    4.8228    0.5669
# 4       NaN     NaN     NaN      NaN     NaN    NaN  ...    2.8348    2.9856
# ..      ...     ...     ...      ...     ...    ...  ...       ...       ...
# 523     NaN     NaN     NaN      NaN     NaN    NaN  ...  217.7653  207.1448
# 524     NaN     NaN     NaN      NaN     NaN    NaN  ...  268.3251  239.7762
# 525     NaN     NaN     NaN      NaN     NaN    NaN  ...   49.7200   51.4100
# 526     NaN     NaN     NaN  23.7599     NaN    NaN  ...   58.7800   60.3000
# 527     NaN     NaN     NaN      NaN     NaN    NaN  ...       NaN       NaN
#
#          2015      2016      2017     2018     2019     2020     2021     2022
# 0     13.1258       NaN       NaN      NaN      NaN      NaN  11.6319  15.3429
# 1     60.7600   61.1930   60.1050  59.9230  60.6190  59.8660  58.9150      NaN
# 2     -0.6617    4.3839    4.9760   0.6261   2.3024      NaN      NaN      NaN
# 3      2.4476   -2.1975    2.4037   2.0713   6.5215   7.8217   0.4774      NaN
# 4      3.1064    3.1222    3.4096   2.7733   2.4879   6.1311   2.6858      NaN
# ..        ...       ...       ...      ...      ...      ...      ...      ...
# 523  122.4957  102.0190   91.5039  61.0165  38.6460  36.8736      NaN      NaN
# 524  221.9158  173.8544  226.3705  85.2163  42.0651  62.5910      NaN      NaN
# 525   55.7933   61.9246       NaN      NaN      NaN      NaN      NaN      NaN
# 526   69.5972   74.4302       NaN      NaN      NaN      NaN      NaN      NaN
# 527   30.7810   35.4028       NaN      NaN      NaN      NaN      NaN      NaN
#
# [528 rows x 40 columns]

# %%
# Agrupar por la columna 'factor_(serie)' y calcular estadísticas resumidas
grouped = df.groupby('factor_(serie)').describe()
grouped
# Out:
#                                                     1987             \
#                                                    count       mean
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)          44.0  69.092136
# Esperanza de vida al nacer, total (años)            44.0  66.426250
# Esperanza de vida al nacer, varones (años)          44.0  63.932773
# Gasto de bolsillo per cápita (US$ actuales)          0.0        NaN
# Gasto interno privado en salud per cápita (US$ ...   0.0        NaN
# Gasto nacional en salud del gobierno general pe...   0.0        NaN
# Inflación, precios al consumidor (% anual)          36.0  16.296367
# Inflación, índice de deflación del PIB (% anual)    41.0  21.285644
# Nivel de instrucción, al menos ciclo inferior d...   0.0        NaN
# Nivel de instrucción, al menos ciclo superior d...   0.0        NaN
# Nivel de instrucción, al menos escuela de nivel...   0.0        NaN
# Tasa de finalización del ciclo inferior de la e...  15.0  57.264807
#
#                                                                         \
#                                                           std      min
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)          11.488663  40.4500
# Esperanza de vida al nacer, total (años)            10.953926  39.8440
# Esperanza de vida al nacer, varones (años)          10.529096  36.7390
# Gasto de bolsillo per cápita (US$ actuales)               NaN      NaN
# Gasto interno privado en salud per cápita (US$ ...        NaN      NaN
# Gasto nacional en salud del gobierno general pe...        NaN      NaN
# Inflación, precios al consumidor (% anual)          42.636358  -6.7121
# Inflación, índice de deflación del PIB (% anual)    47.823632  -8.7010
# Nivel de instrucción, al menos ciclo inferior d...        NaN      NaN
# Nivel de instrucción, al menos ciclo superior d...        NaN      NaN
# Nivel de instrucción, al menos escuela de nivel...        NaN      NaN
# Tasa de finalización del ciclo inferior de la e...  30.394662   0.9178
#
#                                                                         \
#                                                           25%      50%
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)          63.488750  72.8845
# Esperanza de vida al nacer, total (años)            61.780500  69.1420
# Esperanza de vida al nacer, varones (años)          59.830500  65.7925
# Gasto de bolsillo per cápita (US$ actuales)               NaN      NaN
# Gasto interno privado en salud per cápita (US$ ...        NaN      NaN
# Gasto nacional en salud del gobierno general pe...        NaN      NaN
# Inflación, precios al consumidor (% anual)           1.430725   4.9074
# Inflación, índice de deflación del PIB (% anual)     2.193500   5.4020
# Nivel de instrucción, al menos ciclo inferior d...        NaN      NaN
# Nivel de instrucción, al menos ciclo superior d...        NaN      NaN
# Nivel de instrucción, al menos escuela de nivel...        NaN      NaN
# Tasa de finalización del ciclo inferior de la e...  39.313200  53.9461
#
#                                                                          1988  \
#                                                           75%       max count
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)          78.200000   81.3900  44.0
# Esperanza de vida al nacer, total (años)            74.777975   78.4295  44.0
# Esperanza de vida al nacer, varones (años)          72.063500   75.6100  44.0
# Gasto de bolsillo per cápita (US$ actuales)               NaN       NaN   0.0
# Gasto interno privado en salud per cápita (US$ ...        NaN       NaN   0.0
# Gasto nacional en salud del gobierno general pe...        NaN       NaN   0.0
# Inflación, precios al consumidor (% anual)          11.998800  228.3362  36.0
# Inflación, índice de deflación del PIB (% anual)    11.471100  206.2087  41.0
# Nivel de instrucción, al menos ciclo inferior d...        NaN       NaN   0.0
# Nivel de instrucción, al menos ciclo superior d...        NaN       NaN   0.0
# Nivel de instrucción, al menos escuela de nivel...        NaN       NaN   0.0
# Tasa de finalización del ciclo inferior de la e...  81.592350  108.8452  17.0
#
#                                                                ...  \
#                                                          mean  ...
# factor_(serie)                                                 ...
# Esperanza de vida al nacer, mujeres (años)          69.423705  ...
# Esperanza de vida al nacer, total (años)            66.839634  ...
# Esperanza de vida al nacer, varones (años)          64.409114  ...
# Gasto de bolsillo per cápita (US$ actuales)               NaN  ...
# Gasto interno privado en salud per cápita (US$ ...        NaN  ...
# Gasto nacional en salud del gobierno general pe...        NaN  ...
# Inflación, precios al consumidor (% anual)          29.155847  ...
# Inflación, índice de deflación del PIB (% anual)    34.611105  ...
# Nivel de instrucción, al menos ciclo inferior d...        NaN  ...
# Nivel de instrucción, al menos ciclo superior d...        NaN  ...
# Nivel de instrucción, al menos escuela de nivel...        NaN  ...
# Tasa de finalización del ciclo inferior de la e...  51.357747  ...
#
#                                                            2021             \
#                                                             75%        max
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)            83.320000    87.5700
# Esperanza de vida al nacer, total (años)              81.280475    84.4456
# Esperanza de vida al nacer, varones (años)            78.925000    81.9000
# Gasto de bolsillo per cápita (US$ actuales)         1001.783000  1267.8200
# Gasto interno privado en salud per cápita (US$ ...  1364.436300  1549.5345
# Gasto nacional en salud del gobierno general pe...  6654.071975  7717.8848
# Inflación, precios al consumidor (% anual)             4.218850    11.8740
# Inflación, índice de deflación del PIB (% anual)       7.910450   401.5883
# Nivel de instrucción, al menos ciclo inferior d...    84.179550    98.5755
# Nivel de instrucción, al menos ciclo superior d...    73.385050    92.1768
# Nivel de instrucción, al menos escuela de nivel...    55.191900    76.2937
# Tasa de finalización del ciclo inferior de la e...    99.590400   108.7882
#
#                                                     2022             \
#                                                    count       mean
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)           0.0        NaN
# Esperanza de vida al nacer, total (años)             0.0        NaN
# Esperanza de vida al nacer, varones (años)           0.0        NaN
# Gasto de bolsillo per cápita (US$ actuales)          0.0        NaN
# Gasto interno privado en salud per cápita (US$ ...   0.0        NaN
# Gasto nacional en salud del gobierno general pe...   0.0        NaN
# Inflación, precios al consumidor (% anual)          39.0   7.930587
# Inflación, índice de deflación del PIB (% anual)    41.0   9.966890
# Nivel de instrucción, al menos ciclo inferior d...   3.0  39.739867
# Nivel de instrucción, al menos ciclo superior d...   3.0  29.870367
# Nivel de instrucción, al menos escuela de nivel...   2.0  13.763500
# Tasa de finalización del ciclo inferior de la e...  11.0  76.866936
#
#                                                                         \
#                                                           std      min
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                NaN      NaN
# Esperanza de vida al nacer, total (años)                  NaN      NaN
# Esperanza de vida al nacer, varones (años)                NaN      NaN
# Gasto de bolsillo per cápita (US$ actuales)               NaN      NaN
# Gasto interno privado en salud per cápita (US$ ...        NaN      NaN
# Gasto nacional en salud del gobierno general pe...        NaN      NaN
# Inflación, precios al consumidor (% anual)           4.510501   1.9736
# Inflación, índice de deflación del PIB (% anual)    11.389899  -5.5118
# Nivel de instrucción, al menos ciclo inferior d...  21.241161  15.3429
# Nivel de instrucción, al menos ciclo superior d...  16.470658  12.5973
# Nivel de instrucción, al menos escuela de nivel...   0.746563  13.2356
# Tasa de finalización del ciclo inferior de la e...  24.493140  30.7038
#
#                                                                        \
#                                                          25%      50%
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)               NaN      NaN
# Esperanza de vida al nacer, total (años)                 NaN      NaN
# Esperanza de vida al nacer, varones (años)               NaN      NaN
# Gasto de bolsillo per cápita (US$ actuales)              NaN      NaN
# Gasto interno privado en salud per cápita (US$ ...       NaN      NaN
# Gasto nacional en salud del gobierno general pe...       NaN      NaN
# Inflación, precios al consumidor (% anual)           5.77605   7.1722
# Inflación, índice de deflación del PIB (% anual)     5.30400   7.0053
# Nivel de instrucción, al menos ciclo inferior d...  32.54770  49.7525
# Nivel de instrucción, al menos ciclo superior d...  22.10560  31.6139
# Nivel de instrucción, al menos escuela de nivel...  13.49955  13.7635
# Tasa de finalización del ciclo inferior de la e...  67.24530  87.2359
#
#
#                                                          75%       max
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)               NaN       NaN
# Esperanza de vida al nacer, total (años)                 NaN       NaN
# Esperanza de vida al nacer, varones (años)               NaN       NaN
# Gasto de bolsillo per cápita (US$ actuales)              NaN       NaN
# Gasto interno privado en salud per cápita (US$ ...       NaN       NaN
# Gasto nacional en salud del gobierno general pe...       NaN       NaN
# Inflación, precios al consumidor (% anual)           8.90620   27.2083
# Inflación, índice de deflación del PIB (% anual)    10.42580   69.6829
# Nivel de instrucción, al menos ciclo inferior d...  51.93835   54.1242
# Nivel de instrucción, al menos ciclo superior d...  38.50690   45.3999
# Nivel de instrucción, al menos escuela de nivel...  14.02745   14.2914
# Tasa de finalización del ciclo inferior de la e...  96.15905  101.3842
#
# [12 rows x 288 columns]

# %%
df['factor_(serie)'].unique()
# Out:
# array(['Nivel de instrucción, al menos ciclo inferior de la escuela secundaria completo, población de más de 25 años, total (%) (acumulativo)',
#        'Esperanza de vida al nacer, varones (años)',
#        'Inflación, precios al consumidor (% anual)',
#        'Inflación, índice de deflación del PIB (% anual)',
#        'Gasto nacional en salud del gobierno general per cápita (US$ a precios actuales)',
#        'Gasto de bolsillo per cápita (US$ actuales)',
#        'Gasto interno privado en salud per cápita (US$ a precios actuales)',
#        'Esperanza de vida al nacer, mujeres (años)',
#        'Esperanza de vida al nacer, total (años)',
#        'Nivel de instrucción, al menos ciclo superior de la escuela secundaria completo, población de más de 25 años, total (%) (acumulativo)',
#        'Nivel de instrucción, al menos escuela de nivel posterior a la secundaria completa, población de más de 25 años, total (%) (acumulativo)',
#        'Tasa de finalización del ciclo inferior de la educación secundaria, total (% del grupo etario pertinente)'],
#       dtype=object)

# %%
# Eliminar columnas específicas por nombre
columnas_a_eliminar = ['codigo_pais', 'codigo_serie']  # Lista con los nombres de las columnas a eliminar
df = df.drop(columnas_a_eliminar, axis=1)

# %%
# Reorganizar los datos para tener 'factor_(serie)' como índice y los años como valores en una sola columna
df_reorganizado = df.melt(id_vars=['país', 'factor_(serie)'], var_name='Año', value_name='Valor')

# Mostrar el DataFrame reorganizado
df_reorganizado
# Out:
#              país                                     factor_(serie)   Año  \
# 0      Afganistán  Nivel de instrucción, al menos ciclo inferior ...  1987
# 1      Afganistán         Esperanza de vida al nacer, varones (años)  1987
# 2      Afganistán         Inflación, precios al consumidor (% anual)  1987
# 3      Afganistán   Inflación, índice de deflación del PIB (% anual)  1987
# 4      Afganistán  Gasto nacional en salud del gobierno general p...  1987
# ...           ...                                                ...   ...
# 19003   Venezuela        Gasto de bolsillo per cápita (US$ actuales)  2022
# 19004   Venezuela  Gasto nacional en salud del gobierno general p...  2022
# 19005   Venezuela  Nivel de instrucción, al menos ciclo superior ...  2022
# 19006   Venezuela  Nivel de instrucción, al menos ciclo inferior ...  2022
# 19007   Venezuela  Nivel de instrucción, al menos escuela de nive...  2022
#
#         Valor
# 0         NaN
# 1      36.739
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 19003     NaN
# 19004     NaN
# 19005     NaN
# 19006     NaN
# 19007     NaN
#
# [19008 rows x 4 columns]

# %%
# Calcular la matriz de correlación para el DataFrame reorganizado
matriz_correlacion_reorganizado = df_reorganizado.pivot_table(index='país', columns='factor_(serie)', values='Valor').corr()

# Mostrar la matriz de correlación para el DataFrame reorganizado
matriz_correlacion_reorganizado
# Out:
# factor_(serie)                                      Esperanza de vida al nacer, mujeres (años)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                            1.000000
# Esperanza de vida al nacer, total (años)                                              0.996848
# Esperanza de vida al nacer, varones (años)                                            0.986262
# Gasto de bolsillo per cápita (US$ actuales)                                           0.627722
# Gasto interno privado en salud per cápita (US$ ...                                    0.465611
# Gasto nacional en salud del gobierno general pe...                                    0.630840
# Inflación, precios al consumidor (% anual)                                            0.003484
# Inflación, índice de deflación del PIB (% anual)                                      0.009133
# Nivel de instrucción, al menos ciclo inferior d...                                    0.810807
# Nivel de instrucción, al menos ciclo superior d...                                    0.804733
# Nivel de instrucción, al menos escuela de nivel...                                    0.757337
# Tasa de finalización del ciclo inferior de la e...                                    0.774464
#
# factor_(serie)                                      Esperanza de vida al nacer, total (años)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                          0.996848
# Esperanza de vida al nacer, total (años)                                            1.000000
# Esperanza de vida al nacer, varones (años)                                          0.996180
# Gasto de bolsillo per cápita (US$ actuales)                                         0.635993
# Gasto interno privado en salud per cápita (US$ ...                                  0.472830
# Gasto nacional en salud del gobierno general pe...                                  0.642933
# Inflación, precios al consumidor (% anual)                                         -0.024323
# Inflación, índice de deflación del PIB (% anual)                                   -0.023931
# Nivel de instrucción, al menos ciclo inferior d...                                  0.804919
# Nivel de instrucción, al menos ciclo superior d...                                  0.790660
# Nivel de instrucción, al menos escuela de nivel...                                  0.744752
# Tasa de finalización del ciclo inferior de la e...                                  0.767229
#
# factor_(serie)                                      Esperanza de vida al nacer, varones (años)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                            0.986262
# Esperanza de vida al nacer, total (años)                                              0.996180
# Esperanza de vida al nacer, varones (años)                                            1.000000
# Gasto de bolsillo per cápita (US$ actuales)                                           0.637630
# Gasto interno privado en salud per cápita (US$ ...                                    0.475120
# Gasto nacional en salud del gobierno general pe...                                    0.648598
# Inflación, precios al consumidor (% anual)                                           -0.053914
# Inflación, índice de deflación del PIB (% anual)                                     -0.060512
# Nivel de instrucción, al menos ciclo inferior d...                                    0.793748
# Nivel de instrucción, al menos ciclo superior d...                                    0.770293
# Nivel de instrucción, al menos escuela de nivel...                                    0.727489
# Tasa de finalización del ciclo inferior de la e...                                    0.753373
#
# factor_(serie)                                      Gasto de bolsillo per cápita (US$ actuales)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                             0.627722
# Esperanza de vida al nacer, total (años)                                               0.635993
# Esperanza de vida al nacer, varones (años)                                             0.637630
# Gasto de bolsillo per cápita (US$ actuales)                                            1.000000
# Gasto interno privado en salud per cápita (US$ ...                                     0.891440
# Gasto nacional en salud del gobierno general pe...                                     0.777579
# Inflación, precios al consumidor (% anual)                                            -0.118401
# Inflación, índice de deflación del PIB (% anual)                                      -0.124483
# Nivel de instrucción, al menos ciclo inferior d...                                     0.656157
# Nivel de instrucción, al menos ciclo superior d...                                     0.707006
# Nivel de instrucción, al menos escuela de nivel...                                     0.576051
# Tasa de finalización del ciclo inferior de la e...                                     0.539025
#
# factor_(serie)                                      Gasto interno privado en salud per cápita (US$ a precios actuales)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                                   0.465611
# Esperanza de vida al nacer, total (años)                                                     0.472830
# Esperanza de vida al nacer, varones (años)                                                   0.475120
# Gasto de bolsillo per cápita (US$ actuales)                                                  0.891440
# Gasto interno privado en salud per cápita (US$ ...                                           1.000000
# Gasto nacional en salud del gobierno general pe...                                           0.589759
# Inflación, precios al consumidor (% anual)                                                  -0.090758
# Inflación, índice de deflación del PIB (% anual)                                            -0.104710
# Nivel de instrucción, al menos ciclo inferior d...                                           0.537089
# Nivel de instrucción, al menos ciclo superior d...                                           0.596687
# Nivel de instrucción, al menos escuela de nivel...                                           0.468034
# Tasa de finalización del ciclo inferior de la e...                                           0.400308
#
# factor_(serie)                                      Gasto nacional en salud del gobierno general per cápita (US$ a precios actuales)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                                   0.630840
# Esperanza de vida al nacer, total (años)                                                     0.642933
# Esperanza de vida al nacer, varones (años)                                                   0.648598
# Gasto de bolsillo per cápita (US$ actuales)                                                  0.777579
# Gasto interno privado en salud per cápita (US$ ...                                           0.589759
# Gasto nacional en salud del gobierno general pe...                                           1.000000
# Inflación, precios al consumidor (% anual)                                                  -0.174139
# Inflación, índice de deflación del PIB (% anual)                                            -0.186369
# Nivel de instrucción, al menos ciclo inferior d...                                           0.728448
# Nivel de instrucción, al menos ciclo superior d...                                           0.750660
# Nivel de instrucción, al menos escuela de nivel...                                           0.608760
# Tasa de finalización del ciclo inferior de la e...                                           0.532002
#
# factor_(serie)                                      Inflación, precios al consumidor (% anual)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                            0.003484
# Esperanza de vida al nacer, total (años)                                             -0.024323
# Esperanza de vida al nacer, varones (años)                                           -0.053914
# Gasto de bolsillo per cápita (US$ actuales)                                          -0.118401
# Gasto interno privado en salud per cápita (US$ ...                                   -0.090758
# Gasto nacional en salud del gobierno general pe...                                   -0.174139
# Inflación, precios al consumidor (% anual)                                            1.000000
# Inflación, índice de deflación del PIB (% anual)                                      0.979181
# Nivel de instrucción, al menos ciclo inferior d...                                   -0.060236
# Nivel de instrucción, al menos ciclo superior d...                                   -0.045640
# Nivel de instrucción, al menos escuela de nivel...                                    0.090156
# Tasa de finalización del ciclo inferior de la e...                                   -0.174285
#
# factor_(serie)                                      Inflación, índice de deflación del PIB (% anual)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                                  0.009133
# Esperanza de vida al nacer, total (años)                                                   -0.023931
# Esperanza de vida al nacer, varones (años)                                                 -0.060512
# Gasto de bolsillo per cápita (US$ actuales)                                                -0.124483
# Gasto interno privado en salud per cápita (US$ ...                                         -0.104710
# Gasto nacional en salud del gobierno general pe...                                         -0.186369
# Inflación, precios al consumidor (% anual)                                                  0.979181
# Inflación, índice de deflación del PIB (% anual)                                            1.000000
# Nivel de instrucción, al menos ciclo inferior d...                                         -0.075105
# Nivel de instrucción, al menos ciclo superior d...                                         -0.044358
# Nivel de instrucción, al menos escuela de nivel...                                          0.161212
# Tasa de finalización del ciclo inferior de la e...                                         -0.105874
#
# factor_(serie)                                      Nivel de instrucción, al menos ciclo inferior de la escuela secundaria completo, población de más de 25 años, total (%) (acumulativo)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                                   0.810807
# Esperanza de vida al nacer, total (años)                                                     0.804919
# Esperanza de vida al nacer, varones (años)                                                   0.793748
# Gasto de bolsillo per cápita (US$ actuales)                                                  0.656157
# Gasto interno privado en salud per cápita (US$ ...                                           0.537089
# Gasto nacional en salud del gobierno general pe...                                           0.728448
# Inflación, precios al consumidor (% anual)                                                  -0.060236
# Inflación, índice de deflación del PIB (% anual)                                            -0.075105
# Nivel de instrucción, al menos ciclo inferior d...                                           1.000000
# Nivel de instrucción, al menos ciclo superior d...                                           0.941609
# Nivel de instrucción, al menos escuela de nivel...                                           0.746003
# Tasa de finalización del ciclo inferior de la e...                                           0.814001
#
# factor_(serie)                                      Nivel de instrucción, al menos ciclo superior de la escuela secundaria completo, población de más de 25 años, total (%) (acumulativo)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                                   0.804733
# Esperanza de vida al nacer, total (años)                                                     0.790660
# Esperanza de vida al nacer, varones (años)                                                   0.770293
# Gasto de bolsillo per cápita (US$ actuales)                                                  0.707006
# Gasto interno privado en salud per cápita (US$ ...                                           0.596687
# Gasto nacional en salud del gobierno general pe...                                           0.750660
# Inflación, precios al consumidor (% anual)                                                  -0.045640
# Inflación, índice de deflación del PIB (% anual)                                            -0.044358
# Nivel de instrucción, al menos ciclo inferior d...                                           0.941609
# Nivel de instrucción, al menos ciclo superior d...                                           1.000000
# Nivel de instrucción, al menos escuela de nivel...                                           0.850172
# Tasa de finalización del ciclo inferior de la e...                                           0.778652
#
# factor_(serie)                                      Nivel de instrucción, al menos escuela de nivel posterior a la secundaria completa, población de más de 25 años, total (%) (acumulativo)  \
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                                   0.757337
# Esperanza de vida al nacer, total (años)                                                     0.744752
# Esperanza de vida al nacer, varones (años)                                                   0.727489
# Gasto de bolsillo per cápita (US$ actuales)                                                  0.576051
# Gasto interno privado en salud per cápita (US$ ...                                           0.468034
# Gasto nacional en salud del gobierno general pe...                                           0.608760
# Inflación, precios al consumidor (% anual)                                                   0.090156
# Inflación, índice de deflación del PIB (% anual)                                             0.161212
# Nivel de instrucción, al menos ciclo inferior d...                                           0.746003
# Nivel de instrucción, al menos ciclo superior d...                                           0.850172
# Nivel de instrucción, al menos escuela de nivel...                                           1.000000
# Tasa de finalización del ciclo inferior de la e...                                           0.613437
#
# factor_(serie)                                      Tasa de finalización del ciclo inferior de la educación secundaria, total (% del grupo etario pertinente)
# factor_(serie)
# Esperanza de vida al nacer, mujeres (años)                                                   0.774464
# Esperanza de vida al nacer, total (años)                                                     0.767229
# Esperanza de vida al nacer, varones (años)                                                   0.753373
# Gasto de bolsillo per cápita (US$ actuales)                                                  0.539025
# Gasto interno privado en salud per cápita (US$ ...                                           0.400308
# Gasto nacional en salud del gobierno general pe...                                           0.532002
# Inflación, precios al consumidor (% anual)                                                  -0.174285
# Inflación, índice de deflación del PIB (% anual)                                            -0.105874
# Nivel de instrucción, al menos ciclo inferior d...                                           0.814001
# Nivel de instrucción, al menos ciclo superior d...                                           0.778652
# Nivel de instrucción, al menos escuela de nivel...                                           0.613437
# Tasa de finalización del ciclo inferior de la e...                                           1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Suponiendo que tienes una matriz de correlación llamada 'matriz_correlacion_reorganizado'
# Puedes obtenerla a partir de tu DataFrame reorganizado, como se mencionó previamente

# Crear un mapa de calor de la matriz de correlación
plt.figure(figsize=(14, 11))
# Modificar los nombres de las columnas para que tengan saltos de línea
nuevos_nombres_columnas = [nombre.replace('_', '\n') for nombre in matriz_correlacion_reorganizado.columns]

# Crear el mapa de calor con los nombres modificados
sns.heatmap(matriz_correlacion_reorganizado, annot=True, cmap='coolwarm', fmt='.2f',
            xticklabels=nuevos_nombres_columnas, yticklabels=nuevos_nombres_columnas)
plt.title('Mapa de calor de la matriz de correlación')
plt.show()
