# %% [markdown]
# # Análisis Exploratorio de Datos

# %% [markdown]
# Se importa las librerias a utilizar

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# Se crea un DataFrame con los datos de la Categoría Educación

# %%
df = pd.read_csv('data_educacion.csv')

# %% [markdown]
# Un .info() para tener idea de cuantas columnas y que tipo de datos hay en cada una de ellas, y si tenemos datos Nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 40 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   país            176 non-null    object
#  1   codigo_pais     176 non-null    object
#  2   factor_(serie)  176 non-null    object
#  3   codigo_serie    176 non-null    object
#  4   1987            15 non-null     float64
#  5   1988            17 non-null     float64
#  6   1989            20 non-null     float64
#  7   1990            32 non-null     float64
#  8   1991            32 non-null     float64
#  9   1992            17 non-null     float64
#  10  1993            17 non-null     float64
#  11  1994            20 non-null     float64
#  12  1995            13 non-null     float64
#  13  1996            13 non-null     float64
#  14  1997            11 non-null     float64
#  15  1998            3 non-null      float64
#  16  1999            15 non-null     float64
#  17  2000            25 non-null     float64
#  18  2001            37 non-null     float64
#  19  2002            40 non-null     float64
#  20  2003            39 non-null     float64
#  21  2004            57 non-null     float64
#  22  2005            63 non-null     float64
#  23  2006            68 non-null     float64
#  24  2007            72 non-null     float64
#  25  2008            68 non-null     float64
#  26  2009            79 non-null     float64
#  27  2010            85 non-null     float64
#  28  2011            87 non-null     float64
#  29  2012            82 non-null     float64
#  30  2013            64 non-null     float64
#  31  2014            89 non-null     float64
#  32  2015            86 non-null     float64
#  33  2016            88 non-null     float64
#  34  2017            75 non-null     float64
#  35  2018            76 non-null     float64
#  36  2019            81 non-null     float64
#  37  2020            83 non-null     float64
#  38  2021            58 non-null     float64
#  39  2022            19 non-null     float64
# dtypes: float64(36), object(4)
# memory usage: 55.1+ KB

# %%
df.head()
# Out:
#          país codigo_pais                                     factor_(serie)  \
# 0  Afganistán         AFG  Nivel de instrucción, al menos ciclo inferior ...
# 1  Afganistán         AFG  Nivel de instrucción, al menos ciclo superior ...
# 2  Afganistán         AFG  Nivel de instrucción, al menos escuela de nive...
# 3  Afganistán         AFG  Tasa de finalización del ciclo inferior de la ...
# 4    Alemania         DEU  Nivel de instrucción, al menos ciclo inferior ...
#
#         codigo_serie  1987  1988  1989  1990  1991  1992  ...     2013  \
# 0  SE.SEC.CUAT.LO.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN
# 1  SE.SEC.CUAT.UP.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN
# 2  SE.SEC.CUAT.PO.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN
# 3  SE.SEC.CMPT.LO.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...      NaN
# 4  SE.SEC.CUAT.LO.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  96.6718
#
#       2014     2015     2016     2017     2018     2019     2020     2021  \
# 0      NaN  13.1258      NaN      NaN      NaN      NaN      NaN  11.6319
# 1      NaN   9.7924      NaN      NaN      NaN      NaN      NaN   9.4613
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN   4.7049
# 3      NaN      NaN  52.5213  54.6933  56.7369  59.7218      NaN      NaN
# 4  96.7991  96.7161  96.5136      NaN  96.3323      NaN  95.6804      NaN
#
#       2022
# 0  15.3429
# 1  12.5973
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# Se utiliza .describe() para obtener una visión general de las estadísticas clave de las columnas numéricas en tu conjunto de datos

# %%
columnas = ['1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001','2002', '2003']
descripcion1 = df[columnas].describe().round(2)
descripcion1
# Out:
#          1987    1988    1989    1990    1991    1992    1993    1994    1995  \
# count   15.00   17.00   20.00   32.00   32.00   17.00   17.00   20.00   13.00
# mean    57.26   51.36   49.96   44.87   48.59   52.60   52.81   65.21   55.92
# std     30.39   34.11   34.30   31.31   29.90   32.28   26.71   30.81   26.68
# min      0.92    1.00    1.58    1.74    1.65    1.70    5.66    5.86    6.07
# 25%     39.31   29.09   23.08   19.53   32.54   31.77   30.13   47.00   32.80
# 50%     53.95   43.84   49.39   36.22   48.12   60.50   48.25   63.79   60.04
# 75%     81.59   79.99   70.32   65.74   63.81   65.78   66.65   87.37   72.71
# max    108.85  108.95  108.20  106.51  106.47  107.71  107.14  111.39  104.56
#
#         1996    1997   1998   1999   2000   2001    2002    2003
# count  13.00   11.00   3.00  15.00  25.00  37.00   40.00   39.00
# mean   44.84   55.52  88.49  64.48  45.75  44.11   54.14   55.11
# std    28.72   28.12  15.40  25.45  28.78  26.44   27.69   27.54
# min     6.47    5.98  70.81  24.85   4.27   4.57    4.17    4.59
# 25%    25.58   39.76  83.27  42.65  30.06  24.69   36.13   35.80
# 50%    45.12   64.10  95.72  62.50  41.84  41.50   50.00   55.76
# 75%    61.87   71.19  97.33  84.29  67.01  62.94   81.04   79.25
# max    99.16  101.06  98.93  98.69  98.68  98.82  101.33  102.24

# %% [markdown]
# El análisis se divide en dos secciones debido al amplio rango de años considerado, que abarca desde 1987 hasta 2022. Esta separación facilita la evaluación detallada de los indicadores a lo largo de un extenso período temporal.

# %%
columnas = ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
descripcion2 = df[columnas].describe().round(2)
descripcion2
# Out:
#          2004    2005    2006    2007    2008    2009    2010    2011    2012  \
# count   57.00   63.00   68.00   72.00   68.00   79.00   85.00   87.00   82.00
# mean    55.53   57.89   53.04   53.76   57.83   58.46   62.71   61.32   61.17
# std     29.09   27.04   27.01   29.72   27.22   30.24   27.81   28.40   29.72
# min      5.47    6.81    1.84    0.27    1.85    2.04    7.92    9.34    1.70
# 25%     32.51   35.12   32.91   32.10   37.70   33.45   39.47   36.98   37.79
# 50%     57.12   59.33   50.77   52.06   57.74   63.18   65.52   66.57   61.51
# 75%     80.83   80.80   73.79   75.79   79.13   83.69   86.43   86.67   87.47
# max    101.23  101.41  102.53  103.20  103.00  102.46  102.90  105.29  115.66
#
#          2013   2014    2015    2016    2017    2018    2019    2020    2021  \
# count   64.00  89.00   86.00   88.00   75.00   76.00   81.00   83.00   58.00
# mean    64.68  61.41   60.80   65.42   65.34   63.19   64.40   68.78   69.07
# std     26.10  29.42   28.97   25.31   27.54   30.66   30.00   26.55   30.22
# min     11.69   0.00    5.83   13.48    8.16    2.02    4.56   10.96    4.70
# 25%     44.58  37.67   35.25   45.69   46.61   41.03   40.84   49.22   50.28
# 50%     69.16  69.42   68.96   70.01   68.85   68.03   70.41   75.11   75.08
# 75%     89.48  88.31   87.45   89.03   91.27   92.69   91.03   92.51   95.69
# max    100.79  99.86  101.78  107.37  104.85  103.38  129.95  111.69  108.79
#
#          2022
# count   19.00
# mean    56.94
# std     32.17
# min     12.60
# 25%     31.16
# 50%     54.12
# 75%     87.49
# max    101.38

# %% [markdown]
# Este Dataset comprende un extenso periodo, desde 1987 hasta 2022, con un rango variable de observaciones, desde un mínimo de 3 a un máximo de 89. Las desviaciones estándar permanecen consistentes, entre 25 y 32, destacando la dispersión de los datos en cada año. La media de los indicadores se mantiene alrededor de 60-70, mostrando cierta estabilidad a lo largo de las décadas. Los valores mínimo y máximo varían notablemente, desde 0 hasta 12.60 como mínimo, y desde 99.86 hasta 129.95 como máximo, evidenciando la amplitud y diversidad de los datos a lo largo del tiempo. En resumen, el conjunto de datos proporciona un amplio espectro para analizar tendencias, cambios y distribución de indicadores específicos para múltiples países a lo largo de un amplio período temporal.

# %% [markdown]
# Para conocer si tenemos valores faltantes en las columnas de ['país'] ['codigo_pais'] ['factor_(serie)'] ['codigo_serie']

# %%
print(df['país'].isna().sum())
print(df['codigo_pais'].isna().sum())
print(df['factor_(serie)'].isna().sum())
print(df['codigo_serie'].isna().sum())
# Out:
# 0
# 0
# 0
# 0

# %% [markdown]
# Veamos en que países se encuentran en estudio.

# %%
cantidad_paises = len(df['país'].unique())
print('Cantidad de paises en estudio:',cantidad_paises)
pd.DataFrame(df['país'].unique(), columns=['Países'])
# Out:
# Cantidad de paises en estudio: 44
#                         Países
# 0                   Afganistán
# 1                     Alemania
# 2                      Argelia
# 3               Arabia Saudita
# 4                    Argentina
# 5                    Australia
# 6                      Austria
# 7                       Brasil
# 8                 Burkina Faso
# 9                        China
# 10                      Canadá
# 11                     Camboya
# 12                        Chad
# 13                   Dinamarca
# 14                     Ecuador
# 15      Emiratos Árabes Unidos
# 16  Egipto, República Árabe de
# 17                        Cuba
# 18                  Costa Rica
# 19              Estados Unidos
# 20                      España
# 21                        Fiji
# 22                   Finlandia
# 23         Federación de Rusia
# 24                      Grecia
# 25                       India
# 26                   Marruecos
# 27                      México
# 28                       Nepal
# 29                       Níger
# 30                Países Bajos
# 31              Nueva Zelandia
# 32                 Reino Unido
# 33                      Rwanda
# 34                       Samoa
# 35                Sierra Leona
# 36                   Sudáfrica
# 37                    Singapur
# 38                       Suiza
# 39                   Venezuela
# 40                    Colombia
# 41                       Japón
# 42                       Kenya
# 43                     Noruega

# %% [markdown]
# El conjunto de países en estudio refleja una diversidad geográfica significativa, representando un total de 43 naciones. Esta recopilación abarca una amplia distribución global, incluyendo países de distintos continentes, como Asia con naciones como China, India, y Japón; Europa con Alemania, España y Noruega; América con Estados Unidos, Argentina y Venezuela; África con Argelia, Nigeria y Rwanda; Oceanía con Australia, Fiji y Nueva Zelanda, entre otros. Esta diversidad geográfica sugiere una representación global en los datos, proporcionando la oportunidad de estudiar y comparar patrones, tendencias y características distintivas de cada continente en el análisis.

# %% [markdown]
# Veamos que Factores se estudian en la Categoría educación

# %%
cantidad_series = len(df['factor_(serie)'].unique())
print('Cantidad de variables en estudio la categoría Educación:',cantidad_series)
serie_unicos = df['factor_(serie)'].unique()
print(serie_unicos)
# Out:
# Cantidad de variables en estudio la categoría Educación: 4
# ['Nivel de instrucción, al menos ciclo inferior de la escuela secundaria completo, población de más de 25 años, total (%) (acumulativo)'
#  'Nivel de instrucción, al menos ciclo superior de la escuela secundaria completo, población de más de 25 años, total (%) (acumulativo)'
#  'Nivel de instrucción, al menos escuela de nivel posterior a la secundaria completa, población de más de 25 años, total (%) (acumulativo)'
#  'Tasa de finalización del ciclo inferior de la educación secundaria, total (% del grupo etario pertinente)']

# %%
grupos = df.groupby('factor_(serie)').groups

# %%
grupos = df.groupby('factor_(serie)')

# Iterar a través de los grupos y convertirlos en DataFrames individuales
dataframes_por_grupo = {}
for nombre_grupo, grupo in grupos:
    dataframes_por_grupo[nombre_grupo] = grupo.reset_index(drop=True)

# Ahora dataframes_por_grupo contiene un DataFrame por cada grupo

# %%
dataframes_por_grupo['Tasa de finalización del ciclo inferior de la educación secundaria, total (% del grupo etario pertinente)']
# Out:
#                           país codigo_pais  \
# 0                   Afganistán         AFG
# 1                     Alemania         DEU
# 2                      Argelia         DZA
# 3               Arabia Saudita         SAU
# 4                    Argentina         ARG
# 5                    Australia         AUS
# 6                      Austria         AUT
# 7                       Brasil         BRA
# 8                 Burkina Faso         BFA
# 9                        China         CHN
# 10                      Canadá         CAN
# 11                     Camboya         KHM
# 12                        Chad         TCD
# 13                   Dinamarca         DNK
# 14                     Ecuador         ECU
# 15      Emiratos Árabes Unidos         ARE
# 16  Egipto, República Árabe de         EGY
# 17                        Cuba         CUB
# 18                  Costa Rica         CRI
# 19              Estados Unidos         USA
# 20                      España         ESP
# 21                        Fiji         FJI
# 22                   Finlandia         FIN
# 23         Federación de Rusia         RUS
# 24                      Grecia         GRC
# 25                       India         IND
# 26                   Marruecos         MAR
# 27                      México         MEX
# 28                       Nepal         NPL
# 29                       Níger         NER
# 30                Países Bajos         NLD
# 31              Nueva Zelandia         NZL
# 32                 Reino Unido         GBR
# 33                      Rwanda         RWA
# 34                       Samoa         WSM
# 35                Sierra Leona         SLE
# 36                   Sudáfrica         ZAF
# 37                    Singapur         SGP
# 38                       Suiza         CHE
# 39                   Venezuela         VEN
# 40                    Colombia         COL
# 41                       Japón         JPN
# 42                       Kenya         KEN
# 43                     Noruega         NOR
#
#                                        factor_(serie)       codigo_serie  \
# 0   Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 1   Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 2   Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 3   Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 4   Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 5   Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 6   Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 7   Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 8   Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 9   Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 10  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 11  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 12  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 13  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 14  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 15  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 16  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 17  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 18  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 19  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 20  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 21  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 22  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 23  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 24  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 25  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 26  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 27  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 28  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 29  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 30  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 31  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 32  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 33  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 34  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 35  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 36  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 37  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 38  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 39  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 40  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 41  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 42  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
# 43  Tasa de finalización del ciclo inferior de la ...  SE.SEC.CMPT.LO.ZS
#
#         1987      1988      1989      1990      1991      1992  ...      2013  \
# 0        NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 1        NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 2        NaN       NaN   61.9400   58.7560   57.8834   60.4996  ...   89.6741
# 3        NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 4        NaN       NaN       NaN       NaN       NaN       NaN  ...   88.3374
# 5        NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 6        NaN       NaN       NaN       NaN       NaN       NaN  ...  100.0143
# 7    37.1231       NaN       NaN       NaN       NaN   46.5011  ...       NaN
# 8        NaN    4.1818    4.9037    5.0818    5.1251    5.6875  ...   20.9734
# 9        NaN       NaN       NaN   56.7808   58.0583   62.9394  ...       NaN
# 10       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 11       NaN       NaN       NaN       NaN       NaN       NaN  ...   45.2458
# 12       NaN    4.1964    3.9901    4.6469    4.5768       NaN  ...   17.8208
# 13       NaN       NaN       NaN       NaN       NaN       NaN  ...   99.5459
# 14       NaN       NaN       NaN       NaN       NaN       NaN  ...   92.0762
# 15   53.9461   51.2426   54.4567   56.5308   59.2646   63.2385  ...   58.7969
# 16       NaN       NaN       NaN       NaN       NaN       NaN  ...   73.1651
# 17   76.5255   79.9939   84.1663   85.5856   89.2235   82.8455  ...   91.5236
# 18   26.1487   27.1109   26.0802   28.1752   29.4164   31.7673  ...   54.9922
# 19       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 20   88.3068   92.8489   91.3536   92.6777       NaN       NaN  ...       NaN
# 21       NaN       NaN       NaN       NaN       NaN       NaN  ...   91.2641
# 22  108.8452  108.9529  108.1996  106.5051  106.4739  107.7139  ...   99.1702
# 23       NaN       NaN       NaN       NaN       NaN       NaN  ...   92.3126
# 24   86.6592   87.9153   89.4744   86.2139   87.2349   87.4758  ...   96.9499
# 25   41.5033   42.5589   43.2211       NaN       NaN       NaN  ...       NaN
# 26   27.1278   29.0927   31.3260   32.2730   33.1473   31.1903  ...   63.4698
# 27   62.6848   63.2409   64.2896   62.4028   60.4575   60.8013  ...   86.5377
# 28       NaN   30.2251       NaN       NaN   33.1743   35.9474  ...   80.4496
# 29       NaN       NaN    4.0502    4.5119    4.6661    4.6392  ...   11.6924
# 30   63.8194   66.4042   65.7040   67.4476   65.6777   65.7849  ...       NaN
# 31       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 32       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 33    0.9178    0.9967    1.5826    1.7450    1.6521    1.7005  ...       NaN
# 34       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 35       NaN       NaN       NaN       NaN       NaN       NaN  ...   45.8422
# 36       NaN       NaN       NaN       NaN   70.8149       NaN  ...       NaN
# 37       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 38       NaN       NaN       NaN       NaN       NaN       NaN  ...   96.1659
# 39   41.8910   41.0183   40.4643   40.4400   41.3754   42.1579  ...   78.4518
# 40   43.1848   43.8398   44.3160       NaN       NaN       NaN  ...   75.1914
# 41  100.2886   99.2624  102.5077  105.1409  103.7800  103.3589  ...       NaN
# 42       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 43       NaN       NaN       NaN       NaN       NaN       NaN  ...  100.7934
#
#        2014      2015      2016      2017      2018      2019      2020  \
# 0       NaN       NaN   52.5213   54.6933   56.7369   59.7218       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2   81.3654   76.3357   77.5487       NaN   78.4607   77.2315       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4   88.4963   90.4596   90.7401   91.8130   93.5833   95.9255   95.4993
# 5       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6   98.4089   99.8130   95.8072   98.5185   96.5090   97.7948   96.1188
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8   24.2690   26.5352   29.5893   36.3830   42.2713   40.4124   40.3846
# 9       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 10      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 11  45.5666   48.0836   47.2065   51.3535   54.1561   55.3017   57.9216
# 12      NaN   15.2224   15.5208   15.7409   15.6737       NaN       NaN
# 13  99.2519  100.2437   99.4763  100.4707   99.8799  101.5834  101.9493
# 14  99.0324  101.7779  100.9348   98.0319   96.9423   95.7784  101.9055
# 15  62.9119       NaN       NaN       NaN       NaN  129.9537  111.6907
# 16  72.2138       NaN   76.4384   75.0552   76.4259   80.2930   80.0931
# 17  91.2009   87.3252   86.2761   89.8325   91.1741   91.0324   91.1084
# 18  55.0622   55.3024   54.0397   59.7532   66.9166   71.6437   67.0781
# 19      NaN       NaN       NaN  104.8523  103.3842  103.4085  103.8459
# 20  88.6862   88.9792   89.0028   90.7269   89.8320   90.2218   90.4282
# 21  92.5082   91.5113   94.9893   93.3483   93.7322   95.4218   96.6632
# 22  99.5763   98.9883   99.4828   99.8045  100.0259   99.9983   99.6362
# 23  90.0349   93.1304   90.2258       NaN   99.4839  100.0813       NaN
# 24  90.3955   90.5969   90.6232   92.7664   93.0551   93.7622   93.8030
# 25  83.1804   82.4347   83.2376   83.1646       NaN   83.2073   85.5816
# 26  66.6902   68.7545   66.5484   64.4376   64.5238   63.8373   66.9742
# 27  87.0949   93.2771   96.7192   98.2658   92.5741   91.4257   90.8839
# 28  84.6845   87.4922   89.4947   93.5122       NaN   98.6788   99.2734
# 29  11.8950   14.9057   16.2383   17.4376   18.6551   17.3960       NaN
# 30      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 31      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 32      NaN       NaN       NaN   98.7536   98.6717   97.1765   95.7202
# 33  36.1722   34.6491   34.3802   35.7259   34.9050   40.1644       NaN
# 34  98.4467  101.0114   99.1487  102.3130   99.9786   98.7686  101.1005
# 35      NaN   45.6021   55.4508   48.3890   48.8556   70.4134   75.9473
# 36      NaN       NaN   85.3260       NaN   88.1688   87.5237   90.2189
# 37      NaN       NaN  107.3664  104.6318   99.6466  100.1598  100.3562
# 38  95.8362   95.7017  100.7327   98.2550   97.4380   95.7274   96.4399
# 39  75.8070   75.1931   73.8208   71.9253       NaN       NaN       NaN
# 40  76.5693   76.9630   77.2069   77.1372   78.6998   79.6781   79.8331
# 41      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 42  79.6227   80.8558   81.5167       NaN       NaN       NaN       NaN
# 43  99.6493   99.6955   99.4464   99.8459   99.7865   99.4301   99.5758
#
#         2021      2022
# 0        NaN       NaN
# 1    62.8736       NaN
# 2    84.5234   76.0697
# 3        NaN       NaN
# 4   108.7882       NaN
# 5        NaN       NaN
# 6    99.6849       NaN
# 7        NaN       NaN
# 8    37.5703   30.7038
# 9        NaN       NaN
# 10       NaN       NaN
# 11   58.2855   62.2023
# 12   19.1755       NaN
# 13  100.3757       NaN
# 14  103.8007   96.8461
# 15       NaN       NaN
# 16   86.1106       NaN
# 17   88.1435   87.7391
# 18   70.7503       NaN
# 19  103.4282       NaN
# 20   94.7044       NaN
# 21  100.1592   95.4720
# 22   99.5950       NaN
# 23       NaN       NaN
# 24   95.2390       NaN
# 25   87.2858   87.2359
# 26   73.8758   72.2883
# 27   92.4205       NaN
# 28   95.8379  101.3842
# 29   15.9748       NaN
# 30       NaN       NaN
# 31       NaN       NaN
# 32   96.6136       NaN
# 33   41.0067   37.0175
# 34  100.3685   98.5774
# 35   54.9655       NaN
# 36   97.2313       NaN
# 37   97.7594       NaN
# 38   96.1076       NaN
# 39       NaN       NaN
# 40   85.6851       NaN
# 41       NaN       NaN
# 42       NaN       NaN
# 43   99.5858       NaN
#
# [44 rows x 40 columns]

# %%
# Crear una lista con los nombres de los países en el DataFrame
paises = df['país'].unique().tolist()

# Crear un widget de menú desplegable (dropdown) para seleccionar un país
dropdown_paises = widgets.Dropdown(
    options=['Todos'] + paises,  # Opción adicional para mostrar todos los países
    description='Seleccionar país:'
)

# Función para filtrar y mostrar los datos según el país seleccionado
def mostrar_datos_por_pais(pais):
    if pais == 'Todos':
        display(df)  # Muestra todos los datos si se selecciona 'Todos'
    else:
        datos_filtrados = df[df['país'] == pais]
        display(datos_filtrados)

# Interactividad: enlazar el widget de menú desplegable a la función de filtrado
widgets.interactive(mostrar_datos_por_pais, pais=dropdown_paises)
# Out:
# interactive(children=(Dropdown(description='Seleccionar país:', options=('Todos', 'Afganistán', 'Alemania', 'A…

# %%
#Crear una lista con los nombres de los países en el DataFrame
paises = df['país'].unique().tolist()
# Crear un widget de menú desplegable (dropdown) para seleccionar un país
dropdown_paises = widgets.Dropdown(
    options=paises,
    description='Seleccionar país:'
)
# Función para graficar los datos por país seleccionado
def graficar_datos_por_pais(pais):
    datos_pais = df[df['país'] == pais]
    columnas_años = datos_pais.columns[4:]  # Suponiendo que las columnas de años comienzan desde la cuarta columna
    fig = go.Figure()
    for i in range(len(datos_pais)):
        valores = datos_pais.iloc[i, 4:]
        nombre_variable = datos_pais.iloc[i]['factor_(serie)']  # Obtener el nombre de la variable
        fig.add_trace(go.Scatter(x=columnas_años, y=valores, mode='lines+markers', name=nombre_variable))
    fig.update_layout(
        title=f'Datos para {pais}',
        xaxis_title='Año',
        yaxis_title='Valor'
    )
    fig.show()
# Mostrar un widget vacío para eliminar el gráfico por defecto
display(widgets.Output())
# Interactividad: enlazar el widget de menú desplegable a la función de graficado
widgets.interactive(graficar_datos_por_pais, pais=dropdown_paises)
# Out:
# Output()
# interactive(children=(Dropdown(description='Seleccionar país:', options=('Afganistán', 'Alemania', 'Argelia', …

# %%
# Iterar sobre los dataframes
for nombre_grupo, dataframe in dataframes_por_grupo.items():
    # Obtener la lista de columnas para graficar (años)
    columnas_años = dataframe.columns[4:]
    
    # Configurar el gráfico
    plt.figure(figsize=(10, 6))
    plt.title(f'Gráfico para {nombre_grupo}')
    plt.xlabel('Año')
    plt.ylabel('Valor')
    
    # Iterar a través de las filas (paises)
    for i in range(len(dataframe)):
        # Obtener los valores (suponiendo que los valores comienzan en la cuarta columna)
        valores = dataframe.iloc[i, 4:]
        plt.plot(columnas_años, valores, label=dataframe.iloc[i, 0])  # El nombre del país está en la primera columna
    
    # Mostrar leyenda y gráfico
    # Posicionar la leyenda afuera del gráfico
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    # Rotar las etiquetas del eje x a 90 grados
    plt.xticks(rotation=90)
    plt.show()
